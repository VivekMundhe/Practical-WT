# %%
import numpy as np
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist

# %% [markdown]
# load and prepare the MNIST dataset

# %%
(x_train, _), (x_test, _) = mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# build the autoencoder model
input_img = Input(shape=(784,))
encoded = Dense(32, activation='relu')(input_img)
decoded = Dense(784, activation='sigmoid')(encoded)

# build the encoder model
encoded_input = Input(shape=(32,))
encoder = Model(input_img, encoded)

autoencoder = Model(input_img, decoded)

decoder_layer = autoencoder.layers[-1]
decoder = Model(encoded_input, decoder_layer(encoded_input))

# %%
decoder

# %%
x_train.shape
# Out:
# (60000, 784)

# %%
autoencoder.compile(optimizer='adam', loss='mse')

# %%
history = autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 4s 12ms/step - loss: 0.0702 - val_loss: 0.0416
# Epoch 2/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0353 - val_loss: 0.0297
# Epoch 3/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0266 - val_loss: 0.0232
# Epoch 4/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0216 - val_loss: 0.0194
# Epoch 5/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0183 - val_loss: 0.0167
# Epoch 6/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0161 - val_loss: 0.0148
# Epoch 7/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0145 - val_loss: 0.0135
# Epoch 8/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0133 - val_loss: 0.0125
# Epoch 9/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0124 - val_loss: 0.0117
# Epoch 10/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0118 - val_loss: 0.0112
# Epoch 11/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0113 - val_loss: 0.0108
# Epoch 12/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0110 - val_loss: 0.0106
# Epoch 13/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0108 - val_loss: 0.0104
# Epoch 14/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0107 - val_loss: 0.0103
# Epoch 15/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0106 - val_loss: 0.0102
# Epoch 16/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0105 - val_loss: 0.0101
# Epoch 17/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0104 - val_loss: 0.0101
# Epoch 18/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0104 - val_loss: 0.0100
# Epoch 19/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0103 - val_loss: 0.0100
# Epoch 20/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0103 - val_loss: 0.0100
# Epoch 21/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0103 - val_loss: 0.0099
# Epoch 22/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0102 - val_loss: 0.0099
# Epoch 23/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0102 - val_loss: 0.0099
# Epoch 24/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0102 - val_loss: 0.0098
# Epoch 25/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0102 - val_loss: 0.0098
# Epoch 26/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0102 - val_loss: 0.0098
# Epoch 27/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 28/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 29/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 30/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 31/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 32/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0101 - val_loss: 0.0097
# Epoch 33/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 34/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0101 - val_loss: 0.0097
# Epoch 35/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 36/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 37/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 38/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 39/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 40/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 41/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 42/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 43/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 44/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0100 - val_loss: 0.0096
# Epoch 45/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 46/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0099 - val_loss: 0.0097
# Epoch 47/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 48/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 49/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 50/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0099 - val_loss: 0.0096

# %%
# use the encoder and decoder for inference
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 [==============================] - 1s 1ms/step
# 313/313 [==============================] - 0s 1ms/step

# %%
import matplotlib.pyplot as plt
n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# calculate reconstruction error as anomaly score
mse = np.mean(np.power(x_test - decoded_imgs, 2), axis=1)
error_threshold = 2 * mse.mean()

# %%
# detect anomalies
anomalies = mse > error_threshold
print("Found %d anomalies!" % np.sum(anomalies))
# Out:
# Found 577 anomalies!

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
