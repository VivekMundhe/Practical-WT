# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load and preprocess the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
train_labels, test_labels = to_categorical(train_labels), to_categorical(test_labels)

# Load a pre-trained ResNet-50 model without the top (classification) layer
base_model = ResNet50(weights='imagenet', include_top=False)

# Add custom top layers for CIFAR-10 classification
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(10, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Freeze the layers of the pre-trained ResNet-50
for layer in base_model.layers:
    layer.trainable = False

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# Epoch 1/10
# 1563/1563 [==============================] - 39s 17ms/step - loss: 2.0576 - accuracy: 0.2507 - val_loss: 1.8757 - val_accuracy: 0.3258
# Epoch 2/10
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.8768 - accuracy: 0.3156 - val_loss: 1.8861 - val_accuracy: 0.3094
# Epoch 3/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.8302 - accuracy: 0.3374 - val_loss: 1.7727 - val_accuracy: 0.3634
# Epoch 4/10
# 1563/1563 [==============================] - 24s 15ms/step - loss: 1.7923 - accuracy: 0.3509 - val_loss: 1.8679 - val_accuracy: 0.3182
# Epoch 5/10
# 1563/1563 [==============================] - 22s 14ms/step - loss: 1.7689 - accuracy: 0.3611 - val_loss: 1.7932 - val_accuracy: 0.3495
# Epoch 6/10
# 1563/1563 [==============================] - 22s 14ms/step - loss: 1.7437 - accuracy: 0.3703 - val_loss: 1.7377 - val_accuracy: 0.3702
# Epoch 7/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.7279 - accuracy: 0.3795 - val_loss: 1.7846 - val_accuracy: 0.3601
# Epoch 8/10
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.7238 - accuracy: 0.3790 - val_loss: 1.6682 - val_accuracy: 0.4051
# Epoch 9/10
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.7121 - accuracy: 0.3821 - val_loss: 1.6986 - val_accuracy: 0.3927
# Epoch 10/10
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.6990 - accuracy: 0.3904 - val_loss: 1.7163 - val_accuracy: 0.3816
# 313/313 [==============================] - 4s 13ms/step - loss: 1.7163 - accuracy: 0.3816
# Test accuracy: 0.3815999925136566
